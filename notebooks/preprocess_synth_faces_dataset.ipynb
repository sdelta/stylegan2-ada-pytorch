# %% [markdown]
# <a href="https://colab.research.google.com/github/sdelta/ImageGen/blob/main/preprocess_synth_faces_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir dataset

# %%
# !cp drive/MyDrive/datasets/synthetic_faces/* dataset

# %%
!7z l dataset/dataset_100000.zip.001 -ba > files_list.txt

# %%
# !cat files_list.txt | grep -o 'dataset.*png' | grep -v seg > needed_files.txt

# %%
# !cd dataset && 7z x dataset_100000.zip.001 -i@../needed_files.txt
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 8522825728 bytes (8128 MiB)
#
# Extracting archive: dataset_100000.zip.001
# --
# Path = dataset_100000.zip.001
# Type = Split
# Physical Size = 8522825728
# Volumes = 4
# Total Physical Size = 33345085051
# ----
# Path = dataset_100000.zip
# Size = 33345085051
# --
# Path = dataset_100000.zip
# Type = zip
# Physical Size = 33345085051
# 64-bit = +
#
# Everything is Ok
#
# Files: 100000
# Size:       33406754538
# Compressed: 33345085051

# %%
# !ls dataset/dataset_100000 -1 | head
# Out:
# 000000.png
# 000001.png
# 000002.png
# 000003.png
# 000004.png
# 000005.png
# 000006.png
# 000007.png
# 000008.png
# 000009.png

# %%
# !git clone https://github.com/sdelta/stylegan2-ada-pytorch.git
# Out:
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 161, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 161 (delta 16), reused 10 (delta 4), pack-reused 128
# Receiving objects: 100% (161/161), 1.15 MiB | 16.30 MiB/s, done.
# Resolving deltas: 100% (73/73), done.

# %%
# !python stylegan2-ada-pytorch/dataset_tool.py --help
# Out:
# Usage: dataset_tool.py [OPTIONS]
#
#   Convert an image dataset into a dataset
#   archive usable with StyleGAN2 ADA PyTorch.
#
#   The input dataset format is guessed from the
#   --source argument:
#
#   --source *_lmdb/                    Load LSUN dataset
#   --source cifar-10-python.tar.gz     Load CIFAR-10 dataset
#   --source train-images-idx3-ubyte.gz Load MNIST dataset
#   --source path/                      Recursively load all images from path/
#   --source dataset.zip                Recursively load all images from dataset.zip
#
#   Specifying the output format and path:
#
#   --dest /path/to/dir                 Save output files under /path/to/dir
#   --dest /path/to/dataset.zip         Save output files into /path/to/dataset.zip
#
#   The output dataset format can be either an
#   image folder or an uncompressed zip archive.
#   Zip archives makes it easier to move datasets
#   around file servers and clusters, and may
#   offer better training performance on network
# ...

# %%
# !python stylegan2-ada-pytorch/dataset_tool.py --source=dataset --dest=synthetic_256x256.zip \
    --width=256 --height=256
# Out:
# 100% 100000/100000 [38:48<00:00, 42.94it/s]

# %%
# !cp synthetic_256x256.zip  drive/MyDrive/datasets/synthetic_faces/
