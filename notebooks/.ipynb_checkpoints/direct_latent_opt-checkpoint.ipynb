# %%
# !ls
# Out:
# calc_metrics.py			       generate.py	    __pycache__
# dataset_tool.py			       layer_swapping.py    README.md
# dnnlib				       legacy.py	    style_mixing.py
# Dockerfile			       LICENSE.txt	    torch_utils
# docker_run.sh			       metrics		    training
# docs				       optimize_latents.py  train.py
# ffhq-res256-mirror-paper256-noaug.pkl  projector.py	    Untitled.ipynb

# %%
# !pip install click requests tqdm pyspng ninja open_clip_torch imageio-ffmpeg==0.4.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 17.6 MB/s eta 0:00:00:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 22.0 MB/s eta 0:00:00:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.4/182.4 kB 48.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 16.0 MB/s eta 0:00:00
# ...

# %%
# !wget https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/transfer-learning-source-nets/ffhq-res256-mirror-paper256-noaug.pkl
# Out:
# --2023-01-13 09:49:03--  https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/transfer-learning-source-nets/ffhq-res256-mirror-paper256-noaug.pkl
# Resolving nvlabs-fi-cdn.nvidia.com (nvlabs-fi-cdn.nvidia.com)... 108.156.172.78, 108.156.172.126, 108.156.172.71, ...
# Connecting to nvlabs-fi-cdn.nvidia.com (nvlabs-fi-cdn.nvidia.com)|108.156.172.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 295744285 (282M) [binary/octet-stream]
# Saving to: ‘ffhq-res256-mirror-paper256-noaug.pkl’
#
# 100%[======================================>] 295,744,285 31.1MB/s   in 10s
#
# 2023-01-13 09:49:14 (28.1 MB/s) - ‘ffhq-res256-mirror-paper256-noaug.pkl’ saved [295744285/295744285]

# %%
# !python generate.py \
    --network=ffhq-res256-mirror-paper256-noaug.pkl\
    --outdir=test_dir \
    --trunc=1 \
    --seeds=42
# Out:
# Loading networks from "ffhq-res256-mirror-paper256-noaug.pkl"...
# Generating image for seed 42 (0/1) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.

# %%
from PIL import Image
Image.open('test_dir/seed0042.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F2D00B5E490>

# %%
# !python projector.py \
    --network=ffhq-res256-mirror-paper256-noaug.pkl\
    --target=test_dir/seed0042.png\
    --outdir=test_proj_dir

# %%
# !ls test_proj_dir
# Out:
# projected_w.npz  proj.mp4  proj.png  target.png

# %%
Image.open('test_proj_dir/proj.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F2CE4E8CF10>

# %%
# !python optimize_latents.py \
    --network=ffhq-res256-mirror-paper256-noaug.pkl\
    --outdir=test_transfer_dir \
    --phrase='sad face' \
    --alpha=0.005 \
    --num-steps=100 \
    --projected-w=test_proj_dir/projected_w.npz
# Out:
# Loading networks from "ffhq-res256-mirror-paper256-noaug.pkl"...
# Modifying image #0
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# step 0  clip_loss -0.23  reg_loss 0.00
# step 1  clip_loss -0.28  reg_loss 0.02
# step 2  clip_loss -0.28  reg_loss 0.03
# step 3  clip_loss -0.29  reg_loss 0.04
# step 4  clip_loss -0.30  reg_loss 0.05
# step 5  clip_loss -0.31  reg_loss 0.05
# step 6  clip_loss -0.31  reg_loss 0.06
# step 7  clip_loss -0.32  reg_loss 0.06
# step 8  clip_loss -0.32  reg_loss 0.06
# step 9  clip_loss -0.32  reg_loss 0.06
# step 10  clip_loss -0.32  reg_loss 0.06
# step 11  clip_loss -0.32  reg_loss 0.06
# step 12  clip_loss -0.33  reg_loss 0.07
# step 13  clip_loss -0.34  reg_loss 0.07
# step 14  clip_loss -0.34  reg_loss 0.07
# step 15  clip_loss -0.35  reg_loss 0.07
# step 16  clip_loss -0.35  reg_loss 0.07
# step 17  clip_loss -0.36  reg_loss 0.07
# step 18  clip_loss -0.35  reg_loss 0.07
# ...

# %%
# !ls test_transfer_dir
# Out:
# projected_w_00.npz  result_00.png

# %%
Image.open('test_transfer_dir/result_00.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F2D00B6C460>
